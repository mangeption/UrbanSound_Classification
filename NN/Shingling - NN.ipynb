# %%
import glob
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
import time
# %matplotlib inline
plt.style.use('ggplot')

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Ubuntu'
plt.rcParams['font.monospace'] = 'Ubuntu Mono'
plt.rcParams['font.size'] = 12
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 11
plt.rcParams['figure.titlesize'] = 13

# %%
EPSILON = 10e-10
def extract_feature(file_name):
    X, sample_rate = librosa.load(file_name)
    stft = np.abs(librosa.stft(X))
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    #chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
    raw_mel = librosa.feature.melspectrogram(X, sr=sample_rate).T
    mel = np.mean(raw_mel, axis=0)
    processed_mel = raw_mel + EPSILON
    logMel = np.mean(np.log(processed_mel),axis=0)
    #contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
    #tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)
    return mfccs,logMel, mel

def parse_audio_files(parent_dir,sub_dirs,file_ext='*.wav'):
    features, labels, namePath = np.empty((0,296)), np.empty(0), np.empty(0)
    for label, sub_dir in enumerate(sub_dirs):
        for fn in glob.glob(os.path.join(parent_dir, sub_dir, file_ext)):
            mfccs, logmel, mel = extract_feature(fn)
            ext_features = np.hstack([mfccs,logmel, mel])
            features = np.vstack([features,ext_features])
            labels = np.append(labels, fn.split('/')[-1].split('-')[1])
            namePath = np.append(namePath, fn)
    return np.array(features), np.array(labels, dtype = np.int), np.array(namePath, dtype=np.string_)

def one_hot_encode(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    one_hot_encode = np.zeros((n_labels,n_unique_labels))
    one_hot_encode[np.arange(n_labels), labels] = 1
    return one_hot_encode

def one_hot_decode(labels):
    n_labels, n_unique_labels = np.shape(labels)
    one_hot_decode = np.zeros((n_labels))
    for idx in range(n_labels):
        for l in range(n_unique_labels):
            if(labels[idx, l] == 1):
                one_hot_decode[idx] = l
                break;
    return one_hot_decode

# %%
x = extract_feature("../../data/UrbanSound8K/audio/fold1/7061-6-0-0.wav")
nfMfccs = np.shape(x[0])[0]
nfLogMel = np.shape(x[1])[0]
nfMel = np.shape(x[2])[0]

# %%
print "Number of features"
print "* Mfcc: {0}".format(nfMfccs)
print "* logMel {0}".format(nfLogMel)
print "* Mel {0}".format(nfMel)
# Out:
# Number of features
# * Mfcc: 40
# * logMel 128
# * Mel 128

# %%
parent_dir = '../../data/UrbanSound8K/audio/'
sub_dirs = ['fold1']
print "---Extracting features.... ---"
start_time = time.time()
features, labels, file_names = parse_audio_files(parent_dir,sub_dirs)
print "---Loading time: {0} seconds ---".format(time.time() - start_time)
# Out:
# ---Extracting features.... ---
# ---Loading time: 192.633636951 seconds ---

# %%
one_hot_labels = one_hot_encode(labels)

# %% [markdown]
# ### Shingling

# %%
window_length = 10
hop_length = 5

# %%
def shingle_features(features, window_length, hop_length, label): 
    nFrames, nFeatures = np.shape(features)
    if(nFrames >= hop_length):
        nMovingWindow = np.floor((nFrames-hop_length)/(window_length - hop_length))
        new_samples = np.zeros((nMovingWindow, nFeatures*window_length))
        labels = np.zeros(nMovingWindow)
        for window in np.arange(nMovingWindow):
            labels[window] = label
            start = window*hop_length
            end = start + window_length
            new_samples[window,:] = np.concatenate([features[i] for i in np.arange(start, end)], axis=0)
        return new_samples, labels
    return None, None

# %%
def extract_shingled_features(file_name):
    X, sample_rate = librosa.load(file_name)
    label = file_name.split('/')[-1].split('-')[1]
    raw_mfccs = librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T
    raw_mel = librosa.feature.melspectrogram(X, sr=sample_rate).T
    processed_mel = raw_mel + EPSILON
    logmel = np.log(processed_mel)
    features = np.hstack([logmel, raw_mfccs])
    shingled, labels = shingle_features(features, window_length=window_length, hop_length=hop_length, label=label)
    return shingled, labels

# %%
def parse_audio_files(parent_dir,sub_dirs,file_ext='*.wav', shingling=False):
    labels, namePath = np.empty(0), np.empty(0)
    features = np.empty((0,1680))
    for label, sub_dir in enumerate(sub_dirs):
        for fn in glob.glob(os.path.join(parent_dir, sub_dir, file_ext)):
            if(shingling):
                
                shingled, label = extract_shingled_features(fn)
                if(label != None):
                    labels = np.append(labels, label)
                    features = np.vstack([features,shingled])
                    
            else:
                features = np.empty((0,296))
                mfccs, logmel, mel = extract_feature(fn)
                labels = np.append(labels, fn.split('/')[-1].split('-')[1])
                ext_features = np.hstack([logmel, mfccs])
                features = np.vstack([features,ext_features])
                
            namePath = np.append(namePath, fn)
    return np.array(features), np.array(labels, dtype = np.int), np.array(namePath, dtype=np.string_)

# %%
features, labels, file_names = parse_audio_files(parent_dir,sub_dirs, shingling=True)
# Out:
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:8: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:11: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# ../../data/UrbanSound8K/audio/fold1/180937-7-3-11.wav
# ../../data/UrbanSound8K/audio/fold1/193394-3-0-4.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-1-3.wav
# ../../data/UrbanSound8K/audio/fold1/97317-2-0-23.wav
# ../../data/UrbanSound8K/audio/fold1/155202-9-0-42.wav
# ../../data/UrbanSound8K/audio/fold1/78360-4-0-6.wav
# ../../data/UrbanSound8K/audio/fold1/30823-8-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/97317-2-0-34.wav
# ../../data/UrbanSound8K/audio/fold1/103074-7-3-2.wav
# ../../data/UrbanSound8K/audio/fold1/15564-2-0-2.wav
# ../../data/UrbanSound8K/audio/fold1/102106-3-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/124489-9-0-18.wav
# ../../data/UrbanSound8K/audio/fold1/7383-3-1-0.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-3-33.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-2-5.wav
# ../../data/UrbanSound8K/audio/fold1/182800-2-2-1.wav
# ../../data/UrbanSound8K/audio/fold1/59277-0-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/9031-3-4-0.wav
# ../../data/UrbanSound8K/audio/fold1/138031-2-0-7.wav
# ../../data/UrbanSound8K/audio/fold1/138031-2-0-28.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-4-3.wav
# ../../data/UrbanSound8K/audio/fold1/176787-5-0-12.wav
# ../../data/UrbanSound8K/audio/fold1/94868-1-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/77766-9-0-7.wav
# ../../data/UrbanSound8K/audio/fold1/54858-3-2-0.wav
# ../../data/UrbanSound8K/audio/fold1/57320-0-0-34.wav
# ../../data/UrbanSound8K/audio/fold1/193698-2-0-114.wav
# ../../data/UrbanSound8K/audio/fold1/197073-3-7-0.wav
# ../../data/UrbanSound8K/audio/fold1/157867-8-0-9.wav
# ../../data/UrbanSound8K/audio/fold1/103258-5-0-6.wav
# ../../data/UrbanSound8K/audio/fold1/176787-5-0-17.wav
# ../../data/UrbanSound8K/audio/fold1/24074-1-0-9.wav
# ../../data/UrbanSound8K/audio/fold1/46669-4-0-24.wav
# ../../data/UrbanSound8K/audio/fold1/50901-0-1-0.wav
# ../../data/UrbanSound8K/audio/fold1/134717-0-0-16.wav
# ../../data/UrbanSound8K/audio/fold1/103258-5-0-19.wav
# ../../data/UrbanSound8K/audio/fold1/99180-9-0-49.wav
# ../../data/UrbanSound8K/audio/fold1/146186-5-0-6.wav
# ../../data/UrbanSound8K/audio/fold1/143651-2-0-22.wav
# ../../data/UrbanSound8K/audio/fold1/160009-2-0-30.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-1-8.wav
# ../../data/UrbanSound8K/audio/fold1/46918-5-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/124489-9-0-6.wav
# ../../data/UrbanSound8K/audio/fold1/165642-4-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/98223-7-1-0.wav
# ../../data/UrbanSound8K/audio/fold1/203440-3-0-5.wav
# ../../data/UrbanSound8K/audio/fold1/125791-3-0-12.wav
# ../../data/UrbanSound8K/audio/fold1/57320-0-0-24.wav
# ../../data/UrbanSound8K/audio/fold1/46669-4-0-26.wav
# ../../data/UrbanSound8K/audio/fold1/46669-4-0-8.wav
# ../../data/UrbanSound8K/audio/fold1/59277-0-0-1.wav
# ../../data/UrbanSound8K/audio/fold1/176714-2-0-51.wav
# ../../data/UrbanSound8K/audio/fold1/161702-9-0-26.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-2-3.wav
# ../../data/UrbanSound8K/audio/fold1/118279-8-0-2.wav
# ../../data/UrbanSound8K/audio/fold1/176787-5-0-28.wav
# ../../data/UrbanSound8K/audio/fold1/57553-3-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/182800-2-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/172314-9-0-80.wav
# ../../data/UrbanSound8K/audio/fold1/166268-3-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/57320-0-0-33.wav
# ../../data/UrbanSound8K/audio/fold1/146186-5-0-11.wav
# ../../data/UrbanSound8K/audio/fold1/118279-8-0-6.wav
# ../../data/UrbanSound8K/audio/fold1/146186-5-0-7.wav
# ../../data/UrbanSound8K/audio/fold1/103074-7-1-0.wav
# ../../data/UrbanSound8K/audio/fold1/71087-4-1-0.wav
# ../../data/UrbanSound8K/audio/fold1/197318-6-11-0.wav
# ../../data/UrbanSound8K/audio/fold1/97317-2-0-28.wav
# ../../data/UrbanSound8K/audio/fold1/132016-9-0-14.wav
# ../../data/UrbanSound8K/audio/fold1/135776-2-0-85.wav
# ../../data/UrbanSound8K/audio/fold1/137156-9-0-5.wav
# ../../data/UrbanSound8K/audio/fold1/17592-5-1-1.wav
# ../../data/UrbanSound8K/audio/fold1/174276-7-2-0.wav
# ../../data/UrbanSound8K/audio/fold1/31840-3-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/134717-0-0-25.wav
# ../../data/UrbanSound8K/audio/fold1/21684-9-0-5.wav
# ../../data/UrbanSound8K/audio/fold1/157867-8-0-1.wav
# ../../data/UrbanSound8K/audio/fold1/14113-4-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/159738-8-0-19.wav
# ../../data/UrbanSound8K/audio/fold1/174290-6-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/55020-4-0-6.wav
# ../../data/UrbanSound8K/audio/fold1/118279-8-0-10.wav
# ../../data/UrbanSound8K/audio/fold1/57320-0-0-45.wav
# ../../data/UrbanSound8K/audio/fold1/55020-4-0-12.wav
# ../../data/UrbanSound8K/audio/fold1/203356-3-0-3.wav
# ../../data/UrbanSound8K/audio/fold1/127873-0-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/176787-5-0-23.wav
# ../../data/UrbanSound8K/audio/fold1/57320-0-0-7.wav
# ../../data/UrbanSound8K/audio/fold1/150341-3-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/72261-3-0-6.wav
# ../../data/UrbanSound8K/audio/fold1/102305-6-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-3-29.wav
# ../../data/UrbanSound8K/audio/fold1/46656-6-4-0.wav
# ../../data/UrbanSound8K/audio/fold1/174276-7-3-0.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-3-20.wav
# ../../data/UrbanSound8K/audio/fold1/177621-0-0-31.wav
# ../../data/UrbanSound8K/audio/fold1/125791-3-0-13.wav
# ../../data/UrbanSound8K/audio/fold1/151977-0-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/55020-4-0-10.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-3-32.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-4-9.wav
# ../../data/UrbanSound8K/audio/fold1/177621-0-0-147.wav
# ../../data/UrbanSound8K/audio/fold1/166268-3-1-0.wav
# ../../data/UrbanSound8K/audio/fold1/137156-9-0-79.wav
# ../../data/UrbanSound8K/audio/fold1/31323-3-0-20.wav
# ../../data/UrbanSound8K/audio/fold1/108041-9-0-4.wav
# ../../data/UrbanSound8K/audio/fold1/65749-3-1-14.wav
# ../../data/UrbanSound8K/audio/fold1/55020-4-0-3.wav
# ../../data/UrbanSound8K/audio/fold1/146186-5-0-5.wav
# ../../data/UrbanSound8K/audio/fold1/99180-9-0-7.wav
# ../../data/UrbanSound8K/audio/fold1/157867-8-0-20.wav
# ../../data/UrbanSound8K/audio/fold1/159738-8-0-11.wav
# ../../data/UrbanSound8K/audio/fold1/176787-5-0-9.wav
# ../../data/UrbanSound8K/audio/fold1/176787-5-0-1.wav
# ../../data/UrbanSound8K/audio/fold1/22962-4-0-2.wav
# ../../data/UrbanSound8K/audio/fold1/73277-9-0-24.wav
# ../../data/UrbanSound8K/audio/fold1/55020-4-0-14.wav
# ../../data/UrbanSound8K/audio/fold1/69304-9-0-14.wav
# ../../data/UrbanSound8K/audio/fold1/143651-2-0-20.wav
# ../../data/UrbanSound8K/audio/fold1/157867-8-0-25.wav
# ../../data/UrbanSound8K/audio/fold1/182800-2-1-0.wav
# ../../data/UrbanSound8K/audio/fold1/164312-3-1-0.wav
# ../../data/UrbanSound8K/audio/fold1/139951-9-0-13.wav
# ../../data/UrbanSound8K/audio/fold1/165067-2-0-9.wav
# ../../data/UrbanSound8K/audio/fold1/146186-5-0-9.wav
# ../../data/UrbanSound8K/audio/fold1/118279-8-0-11.wav
# ../../data/UrbanSound8K/audio/fold1/176787-5-0-27.wav
# ../../data/UrbanSound8K/audio/fold1/172314-9-0-72.wav
# ../../data/UrbanSound8K/audio/fold1/108041-9-0-6.wav
# ../../data/UrbanSound8K/audio/fold1/203356-3-0-2.wav
# ../../data/UrbanSound8K/audio/fold1/197318-6-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-2-9.wav
# ../../data/UrbanSound8K/audio/fold1/156194-1-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/176787-5-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/46669-4-0-45.wav
# ../../data/UrbanSound8K/audio/fold1/78360-4-0-12.wav
# ../../data/UrbanSound8K/audio/fold1/134717-0-0-23.wav
# ../../data/UrbanSound8K/audio/fold1/134717-0-0-1.wav
# ../../data/UrbanSound8K/audio/fold1/46656-6-2-0.wav
# ../../data/UrbanSound8K/audio/fold1/157867-8-0-15.wav
# ../../data/UrbanSound8K/audio/fold1/46669-4-0-35.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-3-17.wav
# ../../data/UrbanSound8K/audio/fold1/55020-4-0-13.wav
# ../../data/UrbanSound8K/audio/fold1/114587-3-0-4.wav
# ../../data/UrbanSound8K/audio/fold1/165645-4-5-0.wav
# ../../data/UrbanSound8K/audio/fold1/17913-4-0-1.wav
# ../../data/UrbanSound8K/audio/fold1/105415-2-0-6.wav
# ../../data/UrbanSound8K/audio/fold1/83199-9-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-2-0.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-2-8.wav
# ../../data/UrbanSound8K/audio/fold1/164053-8-2-3.wav
# ../../data/UrbanSound8K/audio/fold1/57584-4-0-5.wav
# ../../data/UrbanSound8K/audio/fold1/134717-0-0-22.wav
# ../../data/UrbanSound8K/audio/fold1/46654-6-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/26270-9-0-3.wav
# ../../data/UrbanSound8K/audio/fold1/174294-6-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/50901-0-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/157867-8-0-13.wav
# ../../data/UrbanSound8K/audio/fold1/192124-2-0-4.wav
# ../../data/UrbanSound8K/audio/fold1/147764-4-7-0.wav
# ../../data/UrbanSound8K/audio/fold1/108041-9-0-7.wav
# ../../data/UrbanSound8K/audio/fold1/118279-8-0-3.wav
# ../../data/UrbanSound8K/audio/fold1/78360-4-0-23.wav
# ../../data/UrbanSound8K/audio/fold1
0-3.wav
# ../../data/UrbanSound8K/audio/fold1/160009-2-0-5.wav
# ../../data/UrbanSound8K/audio/fold1/97317-2-0-22.wav
# ../../data/UrbanSound8K/audio/fold1/122690-6-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/134717-0-0-15.wav
# ../../data/UrbanSound8K/audio/fold1/134717-0-0-13.wav
# ../../data/UrbanSound8K/audio/fold1/73277-9-0-17.wav
# ../../data/UrbanSound8K/audio/fold1/196079-2-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/46669-4-0-49.wav
# ../../data/UrbanSound8K/audio/fold1/143651-2-0-39.wav
# ../../data/UrbanSound8K/audio/fold1/146186-5-0-4.wav
# ../../data/UrbanSound8K/audio/fold1/108362-2-0-29.wav
# ../../data/UrbanSound8K/audio/fold1/55020-4-0-1.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-4-7.wav
# ../../data/UrbanSound8K/audio/fold1/138015-3-0-7.wav
# ../../data/UrbanSound8K/audio/fold1/103074-7-4-0.wav
# ../../data/UrbanSound8K/audio/fold1/164053-8-2-0.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-4-10.wav
# ../../data/UrbanSound8K/audio/fold1/134717-0-0-26.wav
# ../../data/UrbanSound8K/audio/fold1/113205-5-1-4.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-4-8.wav
# ../../data/UrbanSound8K/audio/fold1/72579-3-0-3.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-4-5.wav
# ../../data/UrbanSound8K/audio/fold1/103074-7-4-6.wav
# ../../data/UrbanSound8K/audio/fold1/46656-6-1-0.wav
# ../../data/UrbanSound8K/audio/fold1/108362-2-0-30.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-3-18.wav
# ../../data/UrbanSound8K/audio/fold1/182800-2-2-2.wav
# ../../data/UrbanSound8K/audio/fold1/157867-8-0-28.wav
# ../../data/UrbanSound8K/audio/fold1/176787-5-0-3.wav
# ../../data/UrbanSound8K/audio/fold1/105415-2-0-4.wav
# ../../data/UrbanSound8K/audio/fold1/57320-0-0-5.wav
# ../../data/UrbanSound8K/audio/fold1/24074-1-0-5.wav
# ../../data/UrbanSound8K/audio/fold1/118279-8-0-13.wav
# ../../data/UrbanSound8K/audio/fold1/77246-6-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/180937-7-1-1.wav
# ../../data/UrbanSound8K/audio/fold1/55020-4-0-5.wav
# ../../data/UrbanSound8K/audio/fold1/161702-9-0-37.wav
# ../../data/UrbanSound8K/audio/fold1/159738-8-0-1.wav
# ../../data/UrbanSound8K/audio/fold1/157867-8-0-27.wav
# ../../data/UrbanSound8K/audio/fold1/78360-4-0-0.wav
# ../../data/UrbanSound8K/audio/fold1/108041-9-0-11.wav
# ../../data/UrbanSound8K/audio/fold1/101415-3-0-2.wav

# %%
np.shape(features)
# Out:
# (33, 1680)

# %%
np.save("nn_shingled_features_fold_1", features, allow_pickle=True)
np.save("nn_labels_fold_1", labels, allow_pickle=True)
np.save("nn_file_names_fold_1", file_names, allow_pickle=True)

# %% [markdown]
# ### Test set

# %%
parent_dir = '../../data/'
sub_dirs = ['test_set_unfolded']
print "---Extracting features.... ---"
start_time = time.time()
test_features, test_labels, test_file_names = parse_audio_files(parent_dir,sub_dirs, shingling=True)
print "---Loading time: {0} seconds ---".format(time.time() - start_time)
# Out:
# ---Extracting features.... ---
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:8: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:11: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# ---Loading time: 23.9566111565 seconds ---

# %%
np.shape(test_labels)
# Out:
# (5419,)

# %%
np.save("nn_shingled_features_test", test_features, allow_pickle=True)
np.save("nn_labels_test", test_labels, allow_pickle=True)
np.save("nn_file_names_test", test_file_names, allow_pickle=True)

# %% [markdown]
# ### Fold 2

# %%
parent_dir = '../../data/UrbanSound8K/audio/'
sub_dirs = ['fold2']
print "---Extracting features.... ---"
start_time = time.time()
features_f2, labels_f2, file_names_f2 = parse_audio_files(parent_dir,sub_dirs, shingling=True)
print "---Loading time: {0} seconds ---".format(time.time() - start_time)
# Out:
# ---Extracting features.... ---
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:8: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:11: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/kyle/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# ---Loading time: 202.471961021 seconds ---

# %%
np.save("nn_shingled_features_fold_2", features_f2, allow_pickle=True)
np.save("nn_labels_fold_2", labels_f2, allow_pickle=True)
np.save("nn_file_names_fold_2", file_names_f2, allow_pickle=True)
